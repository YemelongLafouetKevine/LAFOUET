# %% [markdown]
# # Week 7 Assignment
#
# We've been working with different types of data structures in Python (dictionary, list, etc), how those are represented in JSON documents, and how to write code to access specific data elements. In this week's assignment, you will need to create your own JSON document to store information about yourself and the grades you've received from week 1 to week 4 and the week 6 quiz.  That is, everything you should have received a grade for.  Then you'll need to show me you know how to navigate the JSON in that file.
#
# Different from what we've done in the past, you do not have to write any functions or include any docstrings.  Just create some JSON and write some code.
#
# ---

# %% [markdown]
# ## 7.1 Create a JSON file
#
# Create a JSON file that contains your name, email, year you were born, all of the grades you've received back so far, and a comment about what you thought was most challenging on each of those assignments.  This can be any structure you choose, but make sure it uses a dictionary and a list, and has at least two levels of hierarchy.  That is, it can't just be one big long list.

# %% [markdown]
# First, explain how your data structure is going to look...

# %% [markdown]
# * Put your explanation here in text...
#
# I'll provid a Python code that creates a JSON structure that organizes personal and family information in a clear and hierarchical manner. The main dictionary, `my_data`, will contain three keys: `personal_information`, `family_information`, and `comments`. The `personal_information` section will hold details about me including  my name, email, year of birth, and position within my family. The `family_information` section will capture my family details, such as the names of my parents, the total number of family members, and specific information about immediate siblings, represented as a list of dictionaries, each containing a sibling's name and their position in the order of birth. The `comments` section is intended to provide insights on assignments.

# %% [markdown]
# Then put the actual JSON you've created inside the multiline string below...

# %%
import json

my_data = {
    "personal_information":{
        "name": "Lafouet kevine yemelong",
        "email": "kevine.yemelong@slu.edu",
        "year_of_birth": 1999,
        "position_in_family": "youngest"
                           },
    "family_information":{
        "fathers_name": "lafouet jean baptiste",
        "mothers_name": "Djousse christine",
        "number_of_wives": 5,
        "number_of_family_members": 44,
        "immediate_siblings": 6,
        "immediate_siblings_names":[
            {"name": "Lafouet laurette","position":"first"},
            {"name": "Lafouet eric","position":"second"},
            {"name": "Lafouet claudine","position":"third"},
            {"name": "Lafouet bergson","position":"fourth"},
            {"name":"lafouet junior","position":"fifth"},
            {"name": "Lafouet kevine","position":"sixth"}

        ]
    },
    "comments": {
        "assignment_6":"The most challenging part i faced was handling exceptions.",
        "assignment_7":"Understanding JSON formatting, ensuring the file was written correctly and structuring the data to ease understanding took lots of time."
    },
   }




with open('my_family_info.json', 'w') as json_file:
    json.dump(my_data, json_file, indent=4)

print("JSON file created successfully.")
# Out:
# JSON file created successfully.

# %% [markdown]
# ## 7.2 Do something with your JSON
#
# Now use Python code to do something with the Json above.  Turn it into English text, but make sure that you use at least one loop to access some dict or list content of your JSON.  Below, I've provided some basic code to read in the string above as JSON and return a Python object.  Your job is to work with that data structure and print out the important information like your name, email, and how you did on each assignment.

# %%
import json

with open('/content/my_family_info.json', 'r') as json_file:
    my_data = json.load(json_file)


name = my_data['personal_information']['name']
email = my_data['personal_information']['email']

print(f"Hi my name is {name}, and my email is {email}")

print("\nMy immediate siblings names and positions are;")
for member in my_data['family_information']['immediate_siblings_names']:
    print(f"- {member['name']} ({member['position']})")

print("\nAssignment Comments for week 6 and 7 assignments include:")
for assignment, comment in my_data['comments'].items():
    print(f"{assignment}: {comment}")
# Out:
# Hi my name is Lafouet kevine yemelong, and my email is kevine.yemelong@slu.edu
#
# My immediate siblings names and positions are;
# - Lafouet laurette (first)
# - Lafouet eric (second)
# - Lafouet claudine (third)
# - Lafouet bergson (fourth)
# - lafouet junior (fifth)
# - Lafouet kevine (sixth)
#
# Assignment Comments for week 6 and 7 assignments include:
# assignment_6: The most challenging part i faced was handling exceptions.
# assignment_7: Understanding JSON formatting, ensuring the file was written correctly and structuring the data to ease understanding took lots of time.

# %% [markdown]
# ## 7.3 Reflect
#
# Write a paragraph on any reflections you have. Was this hard? Easy?  What parts were most challenging or easiest? What did you like or dislike about the assignment?  Share whatever important thoughts you have abou this assignment.

# %% [markdown]
# * Put your response here

# %% [markdown]
# Personally this assignment was challenging, but it helped me to think out of the box. The first part was easy since it was about creating a dictionary and list to enable the JSON file structure. However, i faced challenges ensuring that the comments section accurately represented multiple assignments without conflicting key names so it required careful consideration of how to structure the data using JSON formatting. I liked the fact that this assignment enhanced my skills and highlighted the importance of clarity and organization in data representation.

# %% [markdown]
# ---
#
# # Example
#
# Below is an example of something similar, but this uses information my and my friend's kids instead of grades.

# %%
hds5210 = """
{
    "me": {
        "name": "Paul",
        "kids": ["Ellie", "Ada", "Teddy"]
    },
    "friend": {
        "name": "Anny",
        "kids": ["Abby"]
    }
}
"""

import json

info = json.loads(hds5210)

me = info["me"]["name"]
my_kids_count = len(info["me"]["kids"])
kids_list = ", ".join(info["me"]["kids"])
friend = info["friend"]["name"]
friends_kid_count = len(info["friend"]["kids"])
friend_kids = ", ".join(info["friend"]["kids"])
compare = "more" if friends_kid_count > my_kids_count else "fewer"

print(f"Hi, my name is {me}. I've got {my_kids_count} kids. Their names are {kids_list}.")
print(f"My friend, {friend} has {friends_kid_count} kids. That's {compare} than me. Their names are {friends_kid_count}")
# Out:
# Hi, my name is Paul. I've got 3 kids. Their names are Ellie, Ada, Teddy.
# My friend, Anny has 1 kids. That's fewer than me. Their names are 1
